# %%
#from basic_fcn import *
#import transfer_fcn 
#import customfcn1
#import customfcn2
#import voc
import torch.nn as nn
import time
import torch
import gc
import os
import util
#import torchvision.transforms as standard_transforms
import torchvision.transforms.functional as TF
import numpy as np
import unet
from mri_imgmask import *

#MODE = ['lr', 'weight', 'augment', 'unet']
MODE = ['lr', 'weight', 'unet', 'init']
"""
None: baseline
'lr': 4a (lr schedule)
'augment': 4b (data augment)
'weight': 4c (weight)
'custom1': 5a-1 (custom1)
'custom2': 5a-2 (custom2)
'transfer': 5b (transfer)
'unet': 5c (unet)
"""
# Out:
# "\nNone: baseline\n'lr': 4a (lr schedule)\n'augment': 4b (data augment)\n'weight': 4c (weight)\n'custom1': 5a-1 (custom1)\n'custom2': 5a-2 (custom2)\n'transfer': 5b (transfer)\n'unet': 5c (unet)\n"

# %%
class MaskToTensor(object):
    def __call__(self, img):
        return torch.from_numpy(np.array(img, dtype=np.int32)).long()


def init_weights(m):
    if 'transfer' in MODE:
        if isinstance(m, nn.ConvTranspose2d):
            torch.nn.init.xavier_uniform_(m.weight.data)
            torch.nn.init.normal_(m.bias.data) #xavier not applicable for biases
    else:
        if isinstance(m, nn.Conv2d) or isinstance(m, nn.ConvTranspose2d):
            torch.nn.init.xavier_uniform_(m.weight.data)
            torch.nn.init.normal_(m.bias.data) #xavier not applicable for biases

def getClassWeights(dataset, n_class):
    cum_counts = torch.zeros(n_class)
    for iter, (inputs, labels) in enumerate(dataset):
        # inputs: 1x3x256x256, labels: 1x256x256 => 256x256
        labels = torch.squeeze(labels)
        vals, counts = labels.unique(return_counts = True)
        for v, c in zip(vals, counts):
            cum_counts[v.item()] += c.item()
            
        print(f"Cumulative counts at iter {iter}: {cum_counts}")
            
    totalPixels = torch.sum(cum_counts)
    classWeights = 1 - (cum_counts / totalPixels)
    print(f"Class weights: {classWeights}")
    return classWeights

# %%
def train_transform(image, mask):
    image = TF.to_tensor(image)
    mask = torch.from_numpy(np.array(mask, dtype=np.int32)).long()
    image = TF.normalize(image, mean=mean_std[0], std=mean_std[1])
    
    # mask value from 255 to 1
    mask[mask==255] = 1

    if 'augment' in MODE:
        images = list(TF.ten_crop(image, 128))
        masks = list(TF.ten_crop(mask, 128))
        for i in range(10):
            angles = [30, 60]
            for angle in angles:
                msk = masks[i].unsqueeze(0)
                img = TF.rotate(images[i], angle)
                msk = TF.rotate(msk, angle)
                msk = msk.squeeze(0)
                images.append(img)
                masks.append(msk)
                
        image = torch.stack([img for img in images])
        mask = torch.stack([msk for msk in masks])
        
    return image, mask

def valtest_transform(image, mask):
    image = TF.to_tensor(image)
    mask = torch.from_numpy(np.array(mask, dtype=np.int32)).long()
    image = TF.normalize(image, mean=mean_std[0], std=mean_std[1])

    # mask value from 255 to 1
    mask[mask==255] = 1
    
    return image, mask

def sample_transform(image, mask):
    image = torch.from_numpy(np.array(image, dtype=np.int32)).long()
    mask = torch.from_numpy(np.array(mask, dtype=np.int32)).long()
    
    return image, mask

# %%
# ----------------  TODO: move to config file later ------------------------#
root = os.path.join('archive','lgg-mri-segmentation','kaggle_3m')
epochs = 20
n_class = 2
learning_rate = 0.01
early_stop_tolerance = 8
model_save_path = 'model.pth'
mean_std = ([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])

if 'init' in MODE:  # need it only once
    make_trainvaltestCSV(root)
if 'mini' in MODE:
    make_trainvaltestCSV_mini(root, 100)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')  # determine which device to use (cuda or cpu)
# ---------------------------------------------------------------------------#

def get_model():
    model = unet.UNet(n_class=n_class)
    model.apply(init_weights)
    
    if 'transfer' in MODE:
        params_to_update = []
        for name,param in model.named_parameters():
            if param.requires_grad == True:
                params_to_update.append(param)
        optimizer = torch.optim.Adam(params_to_update, lr = learning_rate, weight_decay=0.001)
    else:
        optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    
    if 'lr' in MODE:
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, epochs)
    
    if 'weight' in MODE:
        train_loader_no_shuffle = get_dataloader(root, 'train', transforms=train_transform, batch_size=1, shuffle=False)
        classWeights = getClassWeights(train_loader_no_shuffle, n_class).to(device)
        criterion = nn.CrossEntropyLoss(weight=classWeights) 
    else:
        criterion = nn.CrossEntropyLoss() 
    model = model.to(device)
    model_dict = {'model':model, 'criterion':criterion, 'optimizer':optimizer}
    if 'lr' in MODE:
        model_dict['scheduler'] = scheduler
    return model_dict
# Out:
# Total Data: 1980, Train - 1584, Valid - 198, Test - 198

# %%
def train(train_loader, valid_loader, model_dict):
    best_iou_score = 0.0
    best_loss = 100.0
    early_stop_count = 0
    train_loss_per_epoch = []
    train_iou_per_epoch = []
    train_acc_per_epoch = []
    
    valid_loss_per_epoch = []
    valid_iou_per_epoch = []
    valid_acc_per_epoch = []
    
    model = model_dict['model']
    criterion = model_dict['criterion']
    optimizer = model_dict['optimizer']
    if 'lr' in MODE:
        scheduler = model_dict['scheduler']
    
    for epoch in range(epochs):
        ts = time.time()
        losses = []
        mean_iou_scores = []
        accuracy = []
        for iter, (inputs, labels) in enumerate(train_loader):
            # reset optimizer gradients
            optimizer.zero_grad()

            # both inputs and labels have to reside in the same device as the model's
            inputs =  inputs.to(device)# transfer the input to the same device as the model's
            labels =  labels.to(device) # transfer the labels to the same device as the model's
            
            if 'augment' in MODE:
                # due to crop transform
                b, ncrop, c, h, w = inputs.size()
                inputs = inputs.view(-1, c, h, w)
                b, ncrop, h, w = labels.size()
                labels = labels.view(-1, h, w)
            
            outputs = model(inputs) # Compute outputs. we will not need to transfer the output, it will be automatically in the same device as the model's!

            loss = criterion(outputs, labels)  # calculate loss

            with torch.no_grad():
                losses.append(loss.item())
                _, pred = torch.max(outputs, dim=1)
                acc = util.pixel_acc(pred, labels)
                accuracy.append(acc)
                iou_score = util.iou(pred, labels)
                mean_iou_scores.append(iou_score)
                
            # backpropagate
            loss.backward()

            # update the weights
            optimizer.step()

            if iter % 10 == 0:
                print("epoch{}, iter{}, loss: {}".format(epoch, iter, loss.item()))

        if 'lr' in MODE:
            print(f'Learning rate at epoch {epoch}: {scheduler.get_last_lr()[0]:0.9f}')  # changes every epoch
            # lr scheduler
            scheduler.step()           
                    
        with torch.no_grad():
            train_loss_at_epoch = np.mean(losses)
            train_iou_at_epoch = np.mean(mean_iou_scores)
            train_acc_at_epoch = np.mean(accuracy)

            train_loss_per_epoch.append(train_loss_at_epoch)
            train_iou_per_epoch.append(train_iou_at_epoch)
            train_acc_per_epoch.append(train_acc_at_epoch)

            print("Finishing epoch {}, time elapsed {}".format(epoch, time.time() - ts))

            valid_loss_at_epoch, valid_iou_at_epoch, valid_acc_at_epoch = val(valid_loader, model_dict, epoch)
            valid_loss_per_epoch.append(valid_loss_at_epoch)
            valid_iou_per_epoch.append(valid_iou_at_epoch)
            valid_acc_per_epoch.append(valid_acc_at_epoch)

            if valid_iou_at_epoch > best_iou_score:
                best_iou_score = valid_iou_at_epoch
                # save the best model
            if valid_loss_at_epoch < best_loss:
                print(f"Valid Loss {valid_loss_at_epoch} < Best Loss {best_loss}. (Valid IOU {valid_iou_at_epoch}) Saving Model...")
                best_loss = valid_loss_at_epoch
                early_stop_count = 0
                torch.save(model.state_dict(), model_save_path)
            else:
                early_stop_count += 1
                if early_stop_count > early_stop_tolerance:
                    print("Early Stopping...")
                    break
    model.load_state_dict(torch.load(model_save_path))
            
    return best_iou_score, train_loss_per_epoch, train_iou_per_epoch, train_acc_per_epoch, valid_loss_per_epoch, valid_iou_per_epoch, valid_acc_per_epoch
    

def val(valid_loader, model_dict, epoch):
    model = model_dict['model']
    criterion = model_dict['criterion']

    model.eval() # Put in eval mode (disables batchnorm/dropout) !
    
    losses = []
    mean_iou_scores = []
    accuracy = []

    with torch.no_grad(): # we don't need to calculate the gradient in the validation/testing
        for iter, (input, label) in enumerate(valid_loader):
            input = input.to(device)
            label = label.to(device)
            
            output = model(input)
            loss = criterion(output, label)
            losses.append(loss.item())
            _, pred = torch.max(output, dim=1)
            acc = util.pixel_acc(pred, label)
            accuracy.append(acc)
            iou_score = util.iou(pred, label)
            mean_iou_scores.append(iou_score)
        loss_at_epoch = np.mean(losses)
        iou_at_epoch = np.mean(mean_iou_scores)
        acc_at_epoch = np.mean(accuracy)

    print(f"Valid Loss at epoch: {epoch} is {loss_at_epoch}")
    print(f"Valid IoU at epoch: {epoch} is {iou_at_epoch}")
    print(f"Valid Pixel acc at epoch: {epoch} is {acc_at_epoch}")

    model.train() #TURNING THE TRAIN MODE BACK ON TO ENABLE BATCHNORM/DROPOUT!!

    return loss_at_epoch, iou_at_epoch, acc_at_epoch


def modelTest(test_loader, model_dict):
    model = model_dict['model']
    criterion = model_dict['criterion']

    model.eval()  # Put in eval mode (disables batchnorm/dropout) !

    image_outputs = []
    image_labels = []
    
    losses = []
    mean_iou_scores = []
    accuracy = []

    with torch.no_grad():  # we don't need to calculate the gradient in the validation/testing

        for iter, (input, label) in enumerate(test_loader):
            input = input.to(device)
            label = label.to(device)

            output = model(input)
            loss = criterion(output, label)
            losses.append(loss.item())
            _, pred = torch.max(output, dim=1)
            acc = util.pixel_acc(pred, label)
            accuracy.append(acc)
            iou_score = util.iou(pred, label)
            mean_iou_scores.append(iou_score)
            
            image_outputs.extend(output)
            image_labels.extend(label)

    test_loss = np.mean(losses)
    test_iou = np.mean(mean_iou_scores)
    test_acc = np.mean(accuracy)

    model.train()  #TURNING THE TRAIN MODE BACK ON TO ENABLE BATCHNORM/DROPOUT!!

    return test_loss, test_iou, test_acc, image_outputs, image_labels

def visualize_image(pred, true):
    figure, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 10))

    ax[0].imshow(pred)
    ax[1].imshow(true)
    ax[0].set_title("Predicted Mask")
    ax[1].set_title("Original Mask")
    
    figure.tight_layout()
    figure.show()

# %%
model_dict = get_model()
train_loader = get_dataloader(root, 'train', transforms=train_transform, batch_size=8, shuffle=True)
valid_loader = get_dataloader(root, 'valid', transforms=valtest_transform, batch_size=8, shuffle=True)
test_loader = get_dataloader(root, 'test', transforms=valtest_transform, batch_size=8, shuffle=True)

val(valid_loader, model_dict, epoch=0)  # show the accuracy before training
# Out:
# train : 3032
# Cumulative counts at iter 0: tensor([65536.,     0.])
# Cumulative counts at iter 1: tensor([131072.,      0.])
# Cumulative counts at iter 2: tensor([196608.,      0.])
# Cumulative counts at iter 3: tensor([258261.,   3883.])
# Cumulative counts at iter 4: tensor([319348.,   8332.])
# Cumulative counts at iter 5: tensor([381779.,  11437.])
# Cumulative counts at iter 6: tensor([447028.,  11724.])
# Cumulative counts at iter 7: tensor([512564.,  11724.])
# Cumulative counts at iter 8: tensor([578100.,  11724.])
# Cumulative counts at iter 9: tensor([643636.,  11724.])
# Cumulative counts at iter 10: tensor([709172.,  11724.])
# Cumulative counts at iter 11: tensor([772620.,  13812.])
# Cumulative counts at iter 12: tensor([834151.,  17817.])
# Cumulative counts at iter 13: tensor([895386.,  22118.])
# Cumulative counts at iter 14: tensor([957943.,  25097.])
# Cumulative counts at iter 15: tensor([1023479.,   25097.])
# Cumulative counts at iter 16: tensor([1089015.,   25097.])
# Cumulative counts at iter 17: tensor([1154551.,   25097.])
# Cumulative counts at iter 18: tensor([1218300.,   26884.])
# Cumulative counts at iter 19: tensor([1279757.,   30963.])
# Cumulative counts at iter 20: tensor([1345293.,   30963.])
# Cumulative counts at iter 21: tensor([1410829.,   30963.])
# Cumulative counts at iter 22: tensor([1476365.,   30963.])
# Cumulative counts at iter 23: tensor([1537936.,   34928.])
# Cumulative counts at iter 24: tensor([1603472.,   34928.])
# Cumulative counts at iter 25: tensor([1669008.,   34928.])
# Cumulative counts at iter 26: tensor([1734544.,   34928.])
# Cumulative counts at iter 27: tensor([1800080.,   34928.])
# Cumulative counts at iter 28: tensor([1865616.,   34928.])
# Cumulative counts at iter 29: tensor([1931152.,   34928.])
# Cumulative counts at iter 30: tensor([1996688.,   34928.])
# Cumulative counts at iter 31: tensor([2062224.,   34928.])
# Cumulative counts at iter 32: tensor([2127760.,   34928.])
# Cumulative counts at iter 33: tensor([2193296.,   34928.])
# Cumulative counts at iter 34: tensor([2258832.,   34928.])
# Cumulative counts at iter 35: tensor([2324368.,   34928.])
# Cumulative counts at iter 36: tensor([2386943.,   37889.])
# Cumulative counts at iter 37: tensor([2449336.,   41032.])
# Cumulative counts at iter 38: tensor([2514872.,   41032.])
# Cumulative counts at iter 39: tensor([2580210.,   41230.])
# Cumulative counts at iter 40: tensor([2642653.,   44323.])
# Cumulative counts at iter 41: tensor([2704256.,   48256.])
# Cumulative counts at iter 42: tensor([2769792.,   48256.])
# Cumulative counts at iter 43: tensor([2835328.,   48256.])
# Cumulative counts at iter 44: tensor([2900864.,   48256.])
# Cumulative counts at iter 45: tensor([2966400.,   48256.])
# Cumulative counts at iter 46: tensor([3031936.,   48256.])
# Cumulative counts at iter 47: tensor([3097472.,   48256.])
# Cumulative counts at iter 48: tensor([3163008.,   48256.])
# Cumulative counts at iter 49: tensor([3228544.,   48256.])
# Cumulative counts at iter 50: tensor([3292743.,   49593.])
# Cumulative counts at iter 51: tensor([3356202.,   51670.])
# Cumulative counts at iter 52: tensor([3419023.,   54385.])
# Cumulative counts at iter 53: tensor([3481536.,   57408.])
# Cumulative counts at iter 54: tensor([3547072.,   57408.])
# Cumulative counts at iter 55: tensor([3612608.,   57408.])
# Cumulative counts at iter 56: tensor([3678144.,   57408.])
# Cumulative counts at iter 57: tensor([3743680.,   57408.])
# Cumulative counts at iter 58: tensor([3808469.,   58155.])
# Cumulative counts at iter 59: tensor([3874005.,   58155.])
# Cumulative counts at iter 60: tensor([3939541.,   58155.])
# Cumulative counts at iter 61: tensor([4005077.,   58155.])
# Cumulative counts at iter 62: tensor([4070613.,   58155.])
# Cumulative counts at iter 63: tensor([4136149.,   58155.])
# Cumulative counts at iter 64: tensor([4201685.,   58155.])
# Cumulative counts at iter 65: tensor([4264607.,   60769.])
# Cumulative counts at iter 66: tensor([4329431.,   61481.])
# Cumulative counts at iter 67: tensor([4393354.,   63094.])
# Cumulative counts at iter 68: tensor([4458890.,   63094.])
# Cumulative counts at iter 69: tensor([4524426.,   63094.])
# Cumulative counts at iter 70: tensor([4589962.,   63094.])
# Cumulative counts at iter 71: tensor([4655498.,   63094.])
# Cumulative counts at iter 72: tensor([4719896.,   64232.])
# Cumulative counts at iter 73: tensor([4784742.,   64922.])
# Cumulative counts at iter 74: tensor([4850127.,   65073.])
# Cumulative counts at iter 75: tensor([4915663.,   65073.])
# Cumulative counts at iter 76: tensor([4979823.,   66449.])
# Cumulative counts at iter 77: tensor([5041642.,   70166.])
# Cumulative counts at iter 78: tensor([5104431.,   72913.])
# Cumulative counts at iter 79: tensor([5169526.,   73354.])
# Cumulative counts at iter 80: tensor([5231199.,   77217.])
# Cumulative counts at iter 81: tensor([5296735.,   77217.])
# Cumulative counts at iter 82: tensor([5362271.,   77217.])
# Cumulative counts at iter 83: tensor([5427807.,   77217.])
# Cumulative counts at iter 84: tensor([5493231.,   77329.])
# Cumulative counts at iter 85: tensor([5558485.,   77611.])
# Cumulative counts at iter 86: tensor([5624021.,   77611.])
# Cumulative counts at iter 87: tensor([5687995.,   79173.])
# Cumulative counts at iter 88: tensor([5753531.,   79173.])
# Cumulative counts at iter 89: tensor([5819067.,   79173.])
# Cumulative counts at iter 90: tensor([5884603.,   79173.])
# Cumulative counts at iter 91: tensor([5950139.,   79173.])
# Cumulative counts at iter 92: tensor([6015675.,   79173.])
# Cumulative counts at iter 93: tensor([6080133.,   80251.])
# Cumulative counts at iter 94: tensor([6142936.,   82984.])
# Cumulative counts at iter 95: tensor([6206117.,   85339.])
# Cumulative counts at iter 96: tensor([6268083.,   88909.])
# Cumulative counts at iter 97: tensor([6331413.,   91115.])
# Cumulative counts at iter 98: tensor([6396949.,   91115.])
# Cumulative counts at iter 99: tensor([6462485.,   91115.])
# Cumulative counts at iter 100: tensor([6525795.,   93341.])
# Cumulative counts at iter 101: tensor([6587922.,   96750.])
# Cumulative counts at iter 102: tensor([6651042.,   99166.])
# Cumulative counts at iter 103: tensor([6712734.,  103010.])
# Cumulative counts at iter 104: tensor([6775049.,  106231.])
# Cumulative counts at iter 105: tensor([6840585.,  106231.])
# Cumulative counts at iter 106: tensor([6906121.,  106231.])
# Cumulative counts at iter 107: tensor([6969050.,  108838.])
# Cumulative counts at iter 108: tensor([7033013.,  110411.])
# Cumulative counts at iter 109: tensor([7098549.,  110411.])
# Cumulative counts at iter 110: tensor([7164085.,  110411.])
# Cumulative counts at iter 111: tensor([7229621.,  110411.])
# Cumulative counts at iter 112: tensor([7292242.,  113326.])
# Cumulative counts at iter 113: tensor([7354967.,  116137.])
# Cumulative counts at iter 114: tensor([7416653.,  119987.])
# Cumulative counts at iter 115: tensor([7477983.,  124193.])
# Cumulative counts at iter 116: tensor([7541047.,  126665.])
# Cumulative counts at iter 117: tensor([7606583.,  126665.])
# Cumulative counts at iter 118: tensor([7672119.,  126665.])
# Cumulative counts at iter 119: tensor([7737655.,  126665.])
# Cumulative counts at iter 120: tensor([7803191.,  126665.])
# Cumulative counts at iter 121: tensor([7868727.,  126665.])
# Cumulative counts at iter 122: tensor([7934263.,  126665.])
# Cumulative counts at iter 123: tensor([7999799.,  126665.])
# Cumulative counts at iter 124: tensor([8063194.,  128806.])
# Cumulative counts at iter 125: tensor([8128730.,  128806.])
# Cumulative counts at iter 126: tensor([8191683.,  131389.])
# Cumulative counts at iter 127: tensor([8257219.,  131389.])
# Cumulative counts at iter 128: tensor([8322755.,  131389.])
# Cumulative counts at iter 129: tensor([8388291.,  131389.])
# Cumulative counts at iter 130: tensor([8451912.,  133304.])
# Cumulative counts at iter 131: tensor([8513841.,  136911.])
# Cumulative counts at iter 132: tensor([8578329.,  137959.])
# Cumulative counts at iter 133: tensor([8643865.,  137959.])
# Cumulative counts at iter 134: tensor([8709401.,  137959.])
# Cumulative counts at iter 135: tensor([8774937.,  137959.])
# Cumulative counts at iter 136: tensor([8840473.,  137959.])
# Cumulative counts at iter 137: tensor([8901240.,  142728.])
# Cumulative counts at iter 138: tensor([8963508.,  145996.])
# Cumulative counts at iter 139: tensor([9023633.,  151407.])
# Cumulative counts at iter 140: tensor([9089169.,  151407.])
# Cumulative counts at iter 141: tensor([9149784.,  156328.])
# Cumulative counts at iter 142: tensor([9215320.,  156328.])
# Cumulative counts at iter 143: tensor([9280856.,  156328.])
# Cumulative counts at iter 144: tensor([9346392.,  156328.])
# Cumulative counts at iter 145: tensor([9411928.,  156328.])
# Cumulative counts at iter 146: tensor([9476555.,  157237.])
# Cumulative counts at iter 147: tensor([9542091.,  157237.])
# Cumulative counts at iter 148: tensor([9603445.,  161419.])
# Cumulative counts at iter 149: tensor([9668981.,  161419.])
# Cumulative counts at iter 150: tensor([9728937.,  166999.])
# Cumulative counts at iter 151: tensor([9794473.,  166999.])
# Cumulative counts at iter 152: tensor([9860009.,  166999.])
# Cumulative counts at iter 153: tensor([9924925.,  167619.])
# Cumulative counts at iter 154: tensor([9990461.,  167619.])
# Cumulative counts at iter 155: tensor([10055997.,   167619.])
# Cumulative counts at iter 156: tensor([10121533.,   167619.])
# Cumulative counts at iter 157: tensor([10186045.,   168643.])
# Cumulative counts at iter 158: tensor([10251581.,   168643.])
# Cumulative counts at iter 159: tensor([10317117.,   168643.])
# Cumulative counts at iter 160: tensor([10382449.,   168847.])
# Cumulative counts at iter 161: tensor([10447985.,   168847.])
# Cumulative counts at iter 162: tensor([10513521.,   168847.])
# Cumulative counts at iter 163: tensor([10579057.,   168847.])
# Cumulative counts at iter 164: tensor([10644593.,   168847.])
# Cumulative counts at iter 165: tensor([10710129.,   168847.])
# Cumulative counts at iter 166: tensor([10775665.,   168847.])
# Cumulative counts at iter 167: tensor([10841201.,   168847.])
# Cumulative counts at iter 168: tensor([10906737.,   168847.])
# Cumulative counts at iter 169: tensor([10971552.,   169568.])
# Cumulative counts at iter 170: tensor([11037088.,   169568.])
# Cumulative counts at iter 171: tensor([11102624.,   169568.])
# Cumulative counts at iter 172: tensor([11167664.,   170064.])
# Cumulative counts at iter 173: tensor([11233200.,   170064.])
# Cumulative counts at iter 174: tensor([11298736.,   170064.])
# Cumulative counts at iter 175: tensor([11364272.,   170064.])
# Cumulative counts at iter 176: tensor([11429808.,   170064.])
# Cumulative counts at iter 177: tensor([11495344.,   170064.])
# Cumulative counts at iter 178: tensor([11560880.,   170064.])
# Cumulative counts at iter 179: tensor([11626416.,   170064.])
# Cumulative counts at iter 180: tensor([11691952.,   170064.])
# Cumulative counts at iter 181: tensor([11757488.,   170064.])
# Cumulative counts at iter 182: tensor([11823024.,   170064.])
# Cumulative counts at iter 183: tensor([11888560.,   170064.])
# Cumulative counts at iter 184: tensor([11954096.,   170064.])
# Cumulative counts at iter 185: tensor([12019632.,   170064.])
# Cumulative counts at iter 186: tensor([12085168.,   170064.])
# Cumulative counts at iter 187: tensor([12150704.,   170064.])
# Cumulative counts at iter 188: tensor([12216240.,   170064.])
# Cumulative counts at iter 189: tensor([12281776.,   170064.])
# Cumulative counts at iter 190: tensor([12347312.,   170064.])
# Cumulative counts at iter 191: tensor([12412848.,   170064.])
# Cumulative counts at iter 192: tensor([12478384.,   170064.])
# Cumulative counts at iter 193: tensor([12543920.,   170064.])
# Cumulative counts at iter 194: tensor([12609162.,   170358.])
# Cumulative counts at iter 195: tensor([12674017.,   171039.])
# Cumulative counts at iter 196: tensor([12739553.,   171039.])
# Cumulative counts at iter 197: tensor([12805089.,   171039.])
# Cumulative counts at iter 198: tensor([12870625.,   171039.])
# Cumulative counts at iter 199: tensor([12936161.,   171039.])
# Cumulative counts at iter 200: tensor([13001697.,   171039.])
# Cumulative counts at iter 201: tensor([13067233.,   171039.])
# Cumulative counts at iter 202: tensor([13132769.,   171039.])
# Cumulative counts at iter 203: tensor([13198305.,   171039.])
# Cumulative counts at iter 204: tensor([13263841.,   171039.])
# Cumulative counts at iter 205: tensor([13329377.,   171039.])
# Cumulative counts at iter 206: tensor([13394913.,   171039.])
# Cumulative counts at iter 207: tensor([13460449.,   171039.])
# Cumulative counts at iter 208: tensor([13525985.,   171039.])
# Cumulative counts at iter 209: tensor([13591521.,   171039.])
# Cumulative counts at iter 210: tensor([13656367.,   171729.])
# Cumulative counts at iter 211: tensor([13721903.,   171729.])
# Cumulative counts at iter 212: tensor([13787347.,   171821.])
# Cumulative counts at iter 213: tensor([13849931.,   174773.])
# Cumulative counts at iter 214: tensor([13912996.,   177244.])
# Cumulative counts at iter 215: tensor([13976483.,   179293.])
# Cumulative counts at iter 216: tensor([14041524.,   179788.])
# Cumulative counts at iter 217: tensor([14106252.,   180596.])
# Cumulative counts at iter 218: tensor([14168715.,   183669.])
# Cumulative counts at iter 219: tensor([14231340.,   186580.])
# Cumulative counts at iter 220: tensor([14296876.,   186580.])
# Cumulative counts at iter 221: tensor([14362412.,   186580.])
# Cumulative counts at iter 222: tensor([14427948.,   186580.])
# Cumulative counts at iter 223: tensor([14493484.,   186580.])
# Cumulative counts at iter 224: tensor([14559020.,   186580.])
# Cumulative counts at iter 225: tensor([14623801.,   187335.])
# Cumulative counts at iter 226: tensor([14687364.,   189308.])
# Cumulative counts at iter 227: tensor([14752493.,   189715.])
# Cumulative counts at iter 228: tensor([14815764.,   191980.])
# Cumulative counts at iter 229: tensor([14878364.,   194916.])
# Cumulative counts at iter 230: tensor([14943900.,   194916.])
# Cumulative counts at iter 231: tensor([15009436.,   194916.])
# Cumulative counts at iter 232: tensor([15074972.,   194916.])
# Cumulative counts at iter 233: tensor([15140508.,   194916.])
# Cumulative counts at iter 234: tensor([15205760.,   195200.])
# Cumulative counts at iter 235: tensor([15268687.,   197809.])
# Cumulative counts at iter 236: tensor([15331108.,   200924.])
# Cumulative counts at iter 237: tensor([15396644.,   200924.])
# Cumulative counts at iter 238: tensor([15462180.,   200924.])
# Cumulative counts at iter 239: tensor([15527716.,   200924.])
# Cumulative counts at iter 240: tensor([15593252.,   200924.])
# Cumulative counts at iter 241: tensor([15658788.,   200924.])
# Cumulative counts at iter 242: tensor([15722020.,   203228.])
# Cumulative counts at iter 243: tensor([15786632.,   204152.])
# Cumulative counts at iter 244: tensor([15852168.,   204152.])
# Cumulative counts at iter 245: tensor([15917390.,   204466.])
# Cumulative counts at iter 246: tensor([15981291.,   206101.])
# Cumulative counts at iter 247: tensor([16043922.,   209006.])
# Cumulative counts at iter 248: tensor([16106806.,   211658.])
# Cumulative counts at iter 249: tensor([16172342.,   211658.])
# Cumulative counts at iter 250: tensor([16237878.,   211658.])
# Cumulative counts at iter 251: tensor([16301823.,   213249.])
# Cumulative counts at iter 252: tensor([16365358.,   215250.])
# Cumulative counts at iter 253: tensor([16430894.,   215250.])
# Cumulative counts at iter 254: tensor([16496430.,   215250.])
# Cumulative counts at iter 255: tensor([16561966.,   215250.])
# Cumulative counts at iter 256: tensor([16627502.,   215250.])
# Cumulative counts at iter 257: tensor([16693038.,   215250.])
# Cumulative counts at iter 258: tensor([16758574.,   215250.])
# Cumulative counts at iter 259: tensor([16821432.,   217929.])
# Cumulative counts at iter 260: tensor([16886968.,   217929.])
# Cumulative counts at iter 261: tensor([16949434.,   220999.])
# Cumulative counts at iter 262: tensor([17013220.,   222750.])
# Cumulative counts at iter 263: tensor([17078756.,   222750.])
# Cumulative counts at iter 264: tensor([17144292.,   222750.])
# Cumulative counts at iter 265: tensor([17209828.,   222750.])
# Cumulative counts at iter 266: tensor([17271202.,   226912.])
# Cumulative counts at iter 267: tensor([17336738.,   226912.])
# Cumulative counts at iter 268: tensor([17398494.,   230692.])
# Cumulative counts at iter 269: tensor([17464030.,   230692.])
# Cumulative counts at iter 270: tensor([17529566.,   230692.])
# Cumulative counts at iter 271: tensor([17595102.,   230692.])
# Cumulative counts at iter 272: tensor([17660528.,   230802.])
# Cumulative counts at iter 273: tensor([17726064.,   230802.])
# Cumulative counts at iter 274: tensor([17788828.,   233573.])
# Cumulative counts at iter 275: tensor([17849616.,   238321.])
# Cumulative counts at iter 276: tensor([17915152.,   238321.])
# Cumulative counts at iter 277: tensor([17980688.,   238321.])
# Cumulative counts at iter 278: tensor([18045876.,   238668.])
# Cumulative counts at iter 279: tensor([18108516.,   241565.])
# Cumulative counts at iter 280: tensor([18174052.,   241565.])
# Cumulative counts at iter 281: tensor([18234512.,   246642.])
# Cumulative counts at iter 282: tensor([18300048.,   246642.])
# Cumulative counts at iter 283: tensor([18359966.,   252260.])
# Cumulative counts at iter 284: tensor([18425502.,   252260.])
# Cumulative counts at iter 285: tensor([18490122.,   253176.])
# Cumulative counts at iter 286: tensor([18555658.,   253176.])
# Cumulative counts at iter 287: tensor([18619602.,   254768.])
# Cumulative counts at iter 288: tensor([18684800.,   255105.])
# Cumulative counts at iter 289: tensor([18748462.,   256979.])
# Cumulative counts at iter 290: tensor([18813168.,   257809.])
# Cumulative counts at iter 291: tensor([18878704.,   257809.])
# Cumulative counts at iter 292: tensor([18944240.,   257809.])
# Cumulative counts at iter 293: tensor([19009776.,   257809.])
# Cumulative counts at iter 294: tensor([19075312.,   257809.])
# Cumulative counts at iter 295: tensor([19140748.,   257910.])
# Cumulative counts at iter 296: tensor([19204786.,   259408.])
# Cumulative counts at iter 297: tensor([19268854.,   260876.])
# Cumulative counts at iter 298: tensor([19334390.,   260876.])
# Cumulative counts at iter 299: tensor([19399926.,   260876.])
# Cumulative counts at iter 300: tensor([19465462.,   260876.])
# Cumulative counts at iter 301: tensor([19530998.,   260876.])
# Cumulative counts at iter 302: tensor([19593858.,   263552.])
# Cumulative counts at iter 303: tensor([19657060.,   265885.])
# Cumulative counts at iter 304: tensor([19722596.,   265885.])
# Cumulative counts at iter 305: tensor([19788132.,   265885.])
# Cumulative counts at iter 306: tensor([19853668.,   265885.])
# Cumulative counts at iter 307: tensor([19919204.,   265885.])
# Cumulative counts at iter 308: tensor([19984740.,   265885.])
# Cumulative counts at iter 309: tensor([20050276.,   265885.])
# Cumulative counts at iter 310: tensor([20115812.,   265885.])
# Cumulative counts at iter 311: tensor([20181084.,   266150.])
# Cumulative counts at iter 312: tensor([20246620.,   266150.])
# Cumulative counts at iter 313: tensor([20312156.,   266150.])
# Cumulative counts at iter 314: tensor([20377298.,   266544.])
# Cumulative counts at iter 315: tensor([20442834.,   266544.])
# Cumulative counts at iter 316: tensor([20508370.,   266544.])
# Cumulative counts at iter 317: tensor([20573906.,   266544.])
# Cumulative counts at iter 318: tensor([20639442.,   266544.])
# Cumulative counts at iter 319: tensor([20704978.,   266544.])
# Cumulative counts at iter 320: tensor([20770514.,   266544.])
# Cumulative counts at iter 321: tensor([20836050.,   266544.])
# Cumulative counts at iter 322: tensor([20901586.,   266544.])
# Cumulative counts at iter 323: tensor([20967122.,   266544.])
# Cumulative counts at iter 324: tensor([21032260.,   266941.])
# Cumulative counts at iter 325: tensor([21096758.,   267979.])
# Cumulative counts at iter 326: tensor([21162294.,   267979.])
# Cumulative counts at iter 327: tensor([21227830.,   267979.])
# Cumulative counts at iter 328: tensor([21293366.,   267979.])
# Cumulative counts at iter 329: tensor([21358902.,   267979.])
# Cumulative counts at iter 330: tensor([21424438.,   267979.])
# Cumulative counts at iter 331: tensor([21489974.,   267979.])
# Cumulative counts at iter 332: tensor([21555510.,   267979.])
# Cumulative counts at iter 333: tensor([21621046.,   267979.])
# Cumulative counts at iter 334: tensor([21686048.,   268513.])
# Cumulative counts at iter 335: tensor([21751584.,   268513.])
# Cumulative counts at iter 336: tensor([21817120.,   268513.])
# Cumulative counts at iter 337: tensor([21882656.,   268513.])
# Cumulative counts at iter 338: tensor([21948192.,   268513.])
# Cumulative counts at iter 339: tensor([22013728.,   268513.])
# Cumulative counts at iter 340: tensor([22079264.,   268513.])
# Cumulative counts at iter 341: tensor([22144800.,   268513.])
# Cumulative counts at iter 342: tensor([22209568.,   269282.])
# Cumulative counts at iter 343: tensor([22275104.,   269282.])
# Cumulative counts at iter 344: tensor([22340070.,   269852.])
# Cumulative counts at iter 345: tensor([22405606.,   269852.])
# Cumulative counts at iter 346: tensor([22471142.,   269852.])
# Cumulative counts at iter 347: tensor([22536678.,   269852.])
# Cumulative counts at iter 348: tensor([22602214.,   269852.])
# Cumulative counts at iter 349: tensor([22667606.,   269996.])
# Cumulative counts at iter 350: tensor([22732928.,   270210.])
# Cumulative counts at iter 351: tensor([22797402.,   271272.])
# Cumulative counts at iter 352: tensor([22862938.,   271272.])
# Cumulative counts at iter 353: tensor([22928474.,   271272.])
# Cumulative counts at iter 354: tensor([22994010.,   271272.])
# Cumulative counts at iter 355: tensor([23059546.,   271272.])
# Cumulative counts at iter 356: tensor([23125082.,   271272.])
# Cumulative counts at iter 357: tensor([23190618.,   271272.])
# Cumulative counts at iter 358: tensor([23256154.,   271272.])
# Cumulative counts at iter 359: tensor([23321690.,   271272.])
# Cumulative counts at iter 360: tensor([23387226.,   271272.])
# Cumulative counts at iter 361: tensor([23452762.,   271272.])
# Cumulative counts at iter 362: tensor([23517664.,   271907.])
# Cumulative counts at iter 363: tensor([23583200.,   271907.])
# Cumulative counts at iter 364: tensor([23647844.,   272798.])
# Cumulative counts at iter 365: tensor([23713380.,   272798.])
# Cumulative counts at iter 366: tensor([23778916.,   272798.])
# Cumulative counts at iter 367: tensor([23844452.,   272798.])
# Cumulative counts at iter 368: tensor([23909988.,   272798.])
# Cumulative counts at iter 369: tensor([23975524.,   272798.])
# Cumulative counts at iter 370: tensor([24039940.,   273917.])
# Cumulative counts at iter 371: tensor([24105188.,   274205.])
# Cumulative counts at iter 372: tensor([24170724.,   274205.])
# Cumulative counts at iter 373: tensor([24236094.,   274371.])
# Cumulative counts at iter 374: tensor([24301630.,   274371.])
# Cumulative counts at iter 375: tensor([24367166.,   274371.])
# Cumulative counts at iter 376: tensor([24432702.,   274371.])
# Cumulative counts at iter 377: tensor([24498238.,   274371.])
# Cumulative counts at iter 378: tensor([24562742.,   275403.])
# Cumulative counts at iter 379: tensor([24627428.,   276254.])
# Cumulative counts at iter 380: tensor([24692964.,   276254.])
# Cumulative counts at iter 381: tensor([24758500.,   276254.])
# Cumulative counts at iter 382: tensor([24824036.,   276254.])
# Cumulative counts at iter 383: tensor([24889572.,   276254.])
# Cumulative counts at iter 384: tensor([24955108.,   276254.])
# Cumulative counts at iter 385: tensor([25020644.,   276254.])
# Cumulative counts at iter 386: tensor([25086180.,   276254.])
# Cumulative counts at iter 387: tensor([25151716.,   276254.])
# Cumulative counts at iter 388: tensor([25217252.,   276254.])
# Cumulative counts at iter 389: tensor([25282788.,   276254.])
# Cumulative counts at iter 390: tensor([25348324.,   276254.])
# Cumulative counts at iter 391: tensor([25413860.,   276254.])
# Cumulative counts at iter 392: tensor([25479396.,   276254.])
# Cumulative counts at iter 393: tensor([25541244.,   279943.])
# Cumulative counts at iter 394: tensor([25606780.,   279943.])
# Cumulative counts at iter 395: tensor([25670092.,   282168.])
# Cumulative counts at iter 396: tensor([25733816.,   283979.])
# Cumulative counts at iter 397: tensor([25797964.,   285368.])
# Cumulative counts at iter 398: tensor([25863500.,   285368.])
# Cumulative counts at iter 399: tensor([25929036.,   285368.])
# Cumulative counts at iter 400: tensor([25994572.,   285368.])
# Cumulative counts at iter 401: tensor([26060108.,   285368.])
# Cumulative counts at iter 402: tensor([26125068.,   285944.])
# Cumulative counts at iter 403: tensor([26188234.,   288314.])
# Cumulative counts at iter 404: tensor([26250608.,   291477.])
# Cumulative counts at iter 405: tensor([26316144.,   291477.])
# Cumulative counts at iter 406: tensor([26377980.,   295178.])
# Cumulative counts at iter 407: tensor([26443516.,   295178.])
# Cumulative counts at iter 408: tensor([26506106.,   298124.])
# Cumulative counts at iter 409: tensor([26571642.,   298124.])
# Cumulative counts at iter 410: tensor([26636264.,   299039.])
# Cumulative counts at iter 411: tensor([26700512.,   300327.])
# Cumulative counts at iter 412: tensor([26766048.,   300327.])
# Cumulative counts at iter 413: tensor([26831584.,   300327.])
# Cumulative counts at iter 414: tensor([26897120.,   300327.])
# Cumulative counts at iter 415: tensor([26962656.,   300327.])
# Cumulative counts at iter 416: tensor([27026688.,   301830.])
# Cumulative counts at iter 417: tensor([27092084.,   301971.])
# Cumulative counts at iter 418: tensor([27157620.,   301971.])
# Cumulative counts at iter 419: tensor([27219768.,   305359.])
# Cumulative counts at iter 420: tensor([27285304.,   305359.])
# Cumulative counts at iter 421: tensor([27350840.,   305359.])
# Cumulative counts at iter 422: tensor([27416376.,   305359.])
# Cumulative counts at iter 423: tensor([27481912.,   305359.])
# Cumulative counts at iter 424: tensor([27547448.,   305359.])
# Cumulative counts at iter 425: tensor([27612984.,   305359.])
# Cumulative counts at iter 426: tensor([27675332.,   308548.])
# Cumulative counts at iter 427: tensor([27737730.,   311686.])
# Cumulative counts at iter 428: tensor([27803266.,   311686.])
# Cumulative counts at iter 429: tensor([27868802.,   311686.])
# Cumulative counts at iter 430: tensor([27934338.,   311686.])
# Cumulative counts at iter 431: tensor([27998936.,   312625.])
# Cumulative counts at iter 432: tensor([28062892.,   314206.])
# Cumulative counts at iter 433: tensor([28128036.,   314598.])
# Cumulative counts at iter 434: tensor([28193572.,   314598.])
# Cumulative counts at iter 435: tensor([28259108.,   314598.])
# Cumulative counts at iter 436: tensor([28321544.,   317699.])
# Cumulative counts at iter 437: tensor([28383946.,   320833.])
# Cumulative counts at iter 438: tensor([28449482.,   320833.])
# Cumulative counts at iter 439: tensor([28515018.,   320833.])
# Cumulative counts at iter 440: tensor([28580554.,   320833.])
# Cumulative counts at iter 441: tensor([28646090.,   320833.])
# Cumulative counts at iter 442: tensor([28708762.,   323697.])
# Cumulative counts at iter 443: tensor([28771870.,   326125.])
# Cumulative counts at iter 444: tensor([28837406.,   326125.])
# Cumulative counts at iter 445: tensor([28902942.,   326125.])
# Cumulative counts at iter 446: tensor([28968478.,   326125.])
# Cumulative counts at iter 447: tensor([29034014.,   326125.])
# Cumulative counts at iter 448: tensor([29098168.,   327506.])
# Cumulative counts at iter 449: tensor([29161074.,   330136.])
# Cumulative counts at iter 450: tensor([29226610.,   330136.])
# Cumulative counts at iter 451: tensor([29292146.,   330136.])
# Cumulative counts at iter 452: tensor([29357682.,   330136.])
# Cumulative counts at iter 453: tensor([29423218.,   330136.])
# Cumulative counts at iter 454: tensor([29488754.,   330136.])
# Cumulative counts at iter 455: tensor([29554290.,   330136.])
# Cumulative counts at iter 456: tensor([29619826.,   330136.])
# Cumulative counts at iter 457: tensor([29685362.,   330136.])
# Cumulative counts at iter 458: tensor([29750898.,   330136.])
# Cumulative counts at iter 459: tensor([29815940.,   330629.])
# Cumulative counts at iter 460: tensor([29880586.,   331519.])
# Cumulative counts at iter 461: tensor([29946122.,   331519.])
# Cumulative counts at iter 462: tensor([30011130.,   332047.])
# Cumulative counts at iter 463: tensor([30075932.,   332781.])
# Cumulative counts at iter 464: tensor([30141468.,   332781.])
# Cumulative counts at iter 465: tensor([30207004.,   332781.])
# Cumulative counts at iter 466: tensor([30272540.,   332781.])
# Cumulative counts at iter 467: tensor([30338076.,   332781.])
# Cumulative counts at iter 468: tensor([30403612.,   332781.])
# Cumulative counts at iter 469: tensor([30469148.,   332781.])
# Cumulative counts at iter 470: tensor([30534684.,   332781.])
# Cumulative counts at iter 471: tensor([30600220.,   332781.])
# Cumulative counts at iter 472: tensor([30665492.,   333044.])
# Cumulative counts at iter 473: tensor([30731028.,   333044.])
# Cumulative counts at iter 474: tensor([30796564.,   333044.])
# Cumulative counts at iter 475: tensor([30862100.,   333044.])
# Cumulative counts at iter 476: tensor([30927636.,   333044.])
# Cumulative counts at iter 477: tensor([30993172.,   333044.])
# Cumulative counts at iter 478: tensor([31058708.,   333044.])
# Cumulative counts at iter 479: tensor([31124244.,   333044.])
# Cumulative counts at iter 480: tensor([31189780.,   333044.])
# Cumulative counts at iter 481: tensor([31255316.,   333044.])
# Cumulative counts at iter 482: tensor([31320408.,   333489.])
# Cumulative counts at iter 483: tensor([31385742.,   333691.])
# Cumulative counts at iter 484: tensor([31451014.,   333955.])
# Cumulative counts at iter 485: tensor([31516550.,   333955.])
# Cumulative counts at iter 486: tensor([31582086.,   333955.])
# Cumulative counts at iter 487: tensor([31647622.,   333955.])
# Cumulative counts at iter 488: tensor([31708820.,   338294.])
# Cumulative counts at iter 489: tensor([31774356.,   338294.])
# Cumulative counts at iter 490: tensor([31834560.,   343627.])
# Cumulative counts at iter 491: tensor([31895638.,   348085.])
# Cumulative counts at iter 492: tensor([31959520.,   349740.])
# Cumulative counts at iter 493: tensor([32022904.,   351891.])
# Cumulative counts at iter 494: tensor([32085384.,   354947.])
# Cumulative counts at iter 495: tensor([32146106.,   359761.])
# Cumulative counts at iter 496: tensor([32208140.,   363264.])
# Cumulative counts at iter 497: tensor([32273676.,   363264.])
# Cumulative counts at iter 498: tensor([32339212.,   363264.])
# Cumulative counts at iter 499: tensor([32404748.,   363264.])
# Cumulative counts at iter 500: tensor([32470284.,   363264.])
# Cumulative counts at iter 501: tensor([32535820.,   363264.])
# Cumulative counts at iter 502: tensor([32595824.,   368796.])
# Cumulative counts at iter 503: tensor([32660220.,   369935.])
# Cumulative counts at iter 504: tensor([32725590.,   370101.])
# Cumulative counts at iter 505: tensor([32791126.,   370101.])
# Cumulative counts at iter 506: tensor([32856662.,   370101.])
# Cumulative counts at iter 507: tensor([32922198.,   370101.])
# Cumulative counts at iter 508: tensor([32987734.,   370101.])
# Cumulative counts at iter 509: tensor([33050450.,   372921.])
# Cumulative counts at iter 510: tensor([33115986.,   372921.])
# Cumulative counts at iter 511: tensor([33179992.,   374450.])
# Cumulative counts at iter 512: tensor([33245528.,   374450.])
# Cumulative counts at iter 513: tensor([33310628.,   374885.])
# Cumulative counts at iter 514: tensor([33376164.,   374885.])
# Cumulative counts at iter 515: tensor([33441260.,   375325.])
# Cumulative counts at iter 516: tensor([33505390.,   376731.])
# Cumulative counts at iter 517: tensor([33565840.,   381815.])
# Cumulative counts at iter 518: tensor([33631376.,   381815.])
# Cumulative counts at iter 519: tensor([33690784.,   387945.])
# Cumulative counts at iter 520: tensor([33750836.,   393428.])
# Cumulative counts at iter 521: tensor([33811780.,   398020.])
# Cumulative counts at iter 522: tensor([33877316.,   398020.])
# Cumulative counts at iter 523: tensor([33942852.,   398020.])
# Cumulative counts at iter 524: tensor([34006120.,   400286.])
# Cumulative counts at iter 525: tensor([34071656.,   400286.])
# Cumulative counts at iter 526: tensor([34133444.,   404035.])
# Cumulative counts at iter 527: tensor([34198980.,   404035.])
# Cumulative counts at iter 528: tensor([34264516.,   404035.])
# Cumulative counts at iter 529: tensor([34330052.,   404035.])
# Cumulative counts at iter 530: tensor([34389864.,   409761.])
# Cumulative counts at iter 531: tensor([34450672.,   414488.])
# Cumulative counts at iter 532: tensor([34509664.,   421030.])
# Cumulative counts at iter 533: tensor([34575200.,   421030.])
# Cumulative counts at iter 534: tensor([34640736.,   421030.])
# Cumulative counts at iter 535: tensor([34705928.,   421374.])
# Cumulative counts at iter 536: tensor([34771464.,   421374.])
# Cumulative counts at iter 537: tensor([34837000.,   421374.])
# Cumulative counts at iter 538: tensor([34900988.,   422922.])
# Cumulative counts at iter 539: tensor([34959920.,   429526.])
# Cumulative counts at iter 540: tensor([35021900.,   433083.])
# Cumulative counts at iter 541: tensor([35087384.,   433133.])
# Cumulative counts at iter 542: tensor([35150280.,   435773.])
# Cumulative counts at iter 543: tensor([35209656.,   441932.])
# Cumulative counts at iter 544: tensor([35274788.,   442336.])
# Cumulative counts at iter 545: tensor([35340324.,   442336.])
# Cumulative counts at iter 546: tensor([35404788.,   443409.])
# Cumulative counts at iter 547: tensor([35470324.,   443409.])
# Cumulative counts at iter 548: tensor([35535860.,   443409.])
# Cumulative counts at iter 549: tensor([35601396.,   443409.])
# Cumulative counts at iter 550: tensor([35666932.,   443409.])
# Cumulative counts at iter 551: tensor([35732468.,   443409.])
# Cumulative counts at iter 552: tensor([35797164.,   444249.])
# Cumulative counts at iter 553: tensor([35861920.,   445030.])
# Cumulative counts at iter 554: tensor([35927456.,   445030.])
# Cumulative counts at iter 555: tensor([35992256.,   445765.])
# Cumulative counts at iter 556: tensor([36057792.,   445765.])
# Cumulative counts at iter 557: tensor([36123328.,   445765.])
# Cumulative counts at iter 558: tensor([36188864.,   445765.])
# Cumulative counts at iter 559: tensor([36254400.,   445765.])
# Cumulative counts at iter 560: tensor([36319936.,   445765.])
# Cumulative counts at iter 561: tensor([36385472.,   445765.])
# Cumulative counts at iter 562: tensor([36451008.,   445765.])
# Cumulative counts at iter 563: tensor([36516544.,   445765.])
# Cumulative counts at iter 564: tensor([36582080.,   445765.])
# Cumulative counts at iter 565: tensor([36647616.,   445765.])
# Cumulative counts at iter 566: tensor([36713152.,   445765.])
# Cumulative counts at iter 567: tensor([36778688.,   445765.])
# Cumulative counts at iter 568: tensor([36844224.,   445765.])
# Cumulative counts at iter 569: tensor([36909760.,   445765.])
# Cumulative counts at iter 570: tensor([36975296.,   445765.])
# Cumulative counts at iter 571: tensor([37040832.,   445765.])
# Cumulative counts at iter 572: tensor([37106368.,   445765.])
# Cumulative counts at iter 573: tensor([37171904.,   445765.])
# Cumulative counts at iter 574: tensor([37237440.,   445765.])
# Cumulative counts at iter 575: tensor([37302976.,   445765.])
# Cumulative counts at iter 576: tensor([37366772.,   447506.])
# Cumulative counts at iter 577: tensor([37428640.,   451173.])
# Cumulative counts at iter 578: tensor([37489656.,   455692.])
# Cumulative counts at iter 579: tensor([37555192.,   455692.])
# Cumulative counts at iter 580: tensor([37620728.,   455692.])
# Cumulative counts at iter 581: tensor([37681760.,   460198.])
# Cumulative counts at iter 582: tensor([37743888.,   463607.])
# Cumulative counts at iter 583: tensor([37806944.,   466086.])
# Cumulative counts at iter 584: tensor([37872480.,   466086.])
# Cumulative counts at iter 585: tensor([37938016.,   466086.])
# Cumulative counts at iter 586: tensor([38003552.,   466086.])
# Cumulative counts at iter 587: tensor([38068680.,   466494.])
# Cumulative counts at iter 588: tensor([38131216.,   469496.])
# Cumulative counts at iter 589: tensor([38192384.,   473866.])
# Cumulative counts at iter 590: tensor([38256008.,   475776.])
# Cumulative counts at iter 591: tensor([38321544.,   475776.])
# Cumulative counts at iter 592: tensor([38387080.,   475776.])
# Cumulative counts at iter 593: tensor([38452616.,   475776.])
# Cumulative counts at iter 594: tensor([38518152.,   475776.])
# Cumulative counts at iter 595: tensor([38582904.,   476562.])
# Cumulative counts at iter 596: tensor([38648440.,   476562.])
# Cumulative counts at iter 597: tensor([38713976.,   476562.])
# Cumulative counts at iter 598: tensor([38779512.,   476562.])
# Cumulative counts at iter 599: tensor([38845048.,   476562.])
# Cumulative counts at iter 600: tensor([38910584.,   476562.])
# Cumulative counts at iter 601: tensor([38974764.,   477918.])
# Cumulative counts at iter 602: tensor([39036572.,   481646.])
# Cumulative counts at iter 603: tensor([39099848.,   483907.])
# Cumulative counts at iter 604: tensor([39165384.,   483907.])
# Cumulative counts at iter 605: tensor([39230796.,   484030.])
# Cumulative counts at iter 606: tensor([39295172.,   485190.])
# Cumulative counts at iter 607: tensor([39359528.,   486368.])
# Cumulative counts at iter 608: tensor([39425064.,   486368.])
# Cumulative counts at iter 609: tensor([39484792.,   492176.])
# Cumulative counts at iter 610: tensor([39550140.,   492363.])
# Cumulative counts at iter 611: tensor([39610856.,   497185.])
# Cumulative counts at iter 612: tensor([39675444.,   498134.])
# Cumulative counts at iter 613: tensor([39738552.,   500560.])
# Cumulative counts at iter 614: tensor([39799720.,   504927.])
# Cumulative counts at iter 615: tensor([39863404.,   506780.])
# Cumulative counts at iter 616: tensor([39928444.,   507275.])
# Cumulative counts at iter 617: tensor([39993980.,   507275.])
# Cumulative counts at iter 618: tensor([40053720.,   513070.])
# Cumulative counts at iter 619: tensor([40119256.,   513070.])
# Cumulative counts at iter 620: tensor([40178380.,   519481.])
# Cumulative counts at iter 621: tensor([40243916.,   519481.])
# Cumulative counts at iter 622: tensor([40309452.,   519481.])
# Cumulative counts at iter 623: tensor([40374988.,   519481.])
# Cumulative counts at iter 624: tensor([40434664.,   525340.])
# Cumulative counts at iter 625: tensor([40500200.,   525340.])
# Cumulative counts at iter 626: tensor([40560128.,   530947.])
# Cumulative counts at iter 627: tensor([40625664.,   530947.])
# Cumulative counts at iter 628: tensor([40691200.,   530947.])
# Cumulative counts at iter 629: tensor([40756736.,   530947.])
# Cumulative counts at iter 630: tensor([40822272.,   530947.])
# Cumulative counts at iter 631: tensor([40887808.,   530947.])
# Cumulative counts at iter 632: tensor([40952984.,   531306.])
# Cumulative counts at iter 633: tensor([41016576.,   533248.])
# Cumulative counts at iter 634: tensor([41080300.,   535061.])
# Cumulative counts at iter 635: tensor([41145836.,   535061.])
# Cumulative counts at iter 636: tensor([41211372.,   535061.])
# Cumulative counts at iter 637: tensor([41276908.,   535061.])
# Cumulative counts at iter 638: tensor([41342444.,   535061.])
# Cumulative counts at iter 639: tensor([41407980.,   535061.])
# Cumulative counts at iter 640: tensor([41473516.,   535061.])
# Cumulative counts at iter 641: tensor([41539052.,   535061.])
# Cumulative counts at iter 642: tensor([41603360.,   536290.])
# Cumulative counts at iter 643: tensor([41667476.,   537711.])
# Cumulative counts at iter 644: tensor([41732168.,   538554.])
# Cumulative counts at iter 645: tensor([41797704.,   538554.])
# Cumulative counts at iter 646: tensor([41863240.,   538554.])
# Cumulative counts at iter 647: tensor([41927880.,   539448.])
# Cumulative counts at iter 648: tensor([41993416.,   539448.])
# Cumulative counts at iter 649: tensor([42058952.,   539448.])
# Cumulative counts at iter 650: tensor([42124488.,   539448.])
# Cumulative counts at iter 651: tensor([42188140.,   541333.])
# Cumulative counts at iter 652: tensor([42253676.,   541333.])
# Cumulative counts at iter 653: tensor([42317180.,   543365.])
# Cumulative counts at iter 654: tensor([42382716.,   543365.])
# Cumulative counts at iter 655: tensor([42448252.,   543365.])
# Cumulative counts at iter 656: tensor([42513788.,   543365.])
# Cumulative counts at iter 657: tensor([42579324.,   543365.])
# Cumulative counts at iter 658: tensor([42642960.,   545264.])
# Cumulative counts at iter 659: tensor([42706688.,   547071.])
# Cumulative counts at iter 660: tensor([42772224.,   547071.])
# Cumulative counts at iter 661: tensor([42837760.,   547071.])
# Cumulative counts at iter 662: tensor([42903236.,   547130.])
# Cumulative counts at iter 663: tensor([42968508.,   547393.])
# Cumulative counts at iter 664: tensor([43034044.,   547393.])
# Cumulative counts at iter 665: tensor([43099580.,   547393.])
# Cumulative counts at iter 666: tensor([43165116.,   547393.])
# Cumulative counts at iter 667: tensor([43230652.,   547393.])
# Cumulative counts at iter 668: tensor([43296188.,   547393.])
# Cumulative counts at iter 669: tensor([43361724.,   547393.])
# Cumulative counts at iter 670: tensor([43426936.,   547718.])
# Cumulative counts at iter 671: tensor([43492472.,   547718.])
# Cumulative counts at iter 672: tensor([43556644.,   549081.])
# Cumulative counts at iter 673: tensor([43622180.,   549081.])
# Cumulative counts at iter 674: tensor([43687716.,   549081.])
# Cumulative counts at iter 675: tensor([43752124.,   550209.])
# Cumulative counts at iter 676: tensor([43817660.,   550209.])
# Cumulative counts at iter 677: tensor([43882656.,   550747.])
# Cumulative counts at iter 678: tensor([43948192.,   550747.])
# Cumulative counts at iter 679: tensor([44013728.,   550747.])
# Cumulative counts at iter 680: tensor([44079264.,   550747.])
# Cumulative counts at iter 681: tensor([44144800.,   550747.])
# Cumulative counts at iter 682: tensor([44210336.,   550747.])
# Cumulative counts at iter 683: tensor([44275872.,   550747.])
# Cumulative counts at iter 684: tensor([44339608.,   552548.])
# Cumulative counts at iter 685: tensor([44403920.,   553770.])
# Cumulative counts at iter 686: tensor([44469456.,   553770.])
# Cumulative counts at iter 687: tensor([44534992.,   553770.])
# Cumulative counts at iter 688: tensor([44600528.,   553770.])
# Cumulative counts at iter 689: tensor([44666064.,   553770.])
# Cumulative counts at iter 690: tensor([44731600.,   553770.])
# Cumulative counts at iter 691: tensor([44797136.,   553770.])
# Cumulative counts at iter 692: tensor([44862672.,   553770.])
# Cumulative counts at iter 693: tensor([44926588.,   555391.])
# Cumulative counts at iter 694: tensor([44992124.,   555391.])
# Cumulative counts at iter 695: tensor([45055928.,   557123.])
# Cumulative counts at iter 696: tensor([45121464.,   557123.])
# Cumulative counts at iter 697: tensor([45187000.,   557123.])
# Cumulative counts at iter 698: tensor([45251996.,   557662.])
# Cumulative counts at iter 699: tensor([45317532.,   557662.])
# Cumulative counts at iter 700: tensor([45383068.,   557662.])
# Cumulative counts at iter 701: tensor([45448604.,   557662.])
# Cumulative counts at iter 702: tensor([45514140.,   557662.])
# Cumulative counts at iter 703: tensor([45578788.,   558550.])
# Cumulative counts at iter 704: tensor([45644324.,   558550.])
# Cumulative counts at iter 705: tensor([45709860.,   558550.])
# Cumulative counts at iter 706: tensor([45775396.,   558550.])
# Cumulative counts at iter 707: tensor([45840932.,   558550.])
# Cumulative counts at iter 708: tensor([45905724.,   559293.])
# Cumulative counts at iter 709: tensor([45970464.,   560089.])
# Cumulative counts at iter 710: tensor([46036000.,   560089.])
# Cumulative counts at iter 711: tensor([46101536.,   560089.])
# Cumulative counts at iter 712: tensor([46167072.,   560089.])
# Cumulative counts at iter 713: tensor([46232608.,   560089.])
# Cumulative counts at iter 714: tensor([46298144.,   560089.])
# Cumulative counts at iter 715: tensor([46362896.,   560873.])
# Cumulative counts at iter 716: tensor([46427864.,   561440.])
# Cumulative counts at iter 717: tensor([46493400.,   561440.])
# Cumulative counts at iter 718: tensor([46558936.,   561440.])
# Cumulative counts at iter 719: tensor([46624472.,   561440.])
# Cumulative counts at iter 720: tensor([46690008.,   561440.])
# Cumulative counts at iter 721: tensor([46755544.,   561440.])
# Cumulative counts at iter 722: tensor([46820172.,   562348.])
# Cumulative counts at iter 723: tensor([46885616.,   562441.])
# Cumulative counts at iter 724: tensor([46950548.,   563044.])
# Cumulative counts at iter 725: tensor([47016084.,   563044.])
# Cumulative counts at iter 726: tensor([47081620.,   563044.])
# Cumulative counts at iter 727: tensor([47146072.,   564128.])
# Cumulative counts at iter 728: tensor([47211608.,   564128.])
# Cumulative counts at iter 729: tensor([47277144.,   564128.])
# Cumulative counts at iter 730: tensor([47342224.,   564582.])
# Cumulative counts at iter 731: tensor([47406800.,   565543.])
# Cumulative counts at iter 732: tensor([47472336.,   565543.])
# Cumulative counts at iter 733: tensor([47537872.,   565543.])
# Cumulative counts at iter 734: tensor([47603408.,   565543.])
# Cumulative counts at iter 735: tensor([47668944.,   565543.])
# Cumulative counts at iter 736: tensor([47734480.,   565543.])
# Cumulative counts at iter 737: tensor([47800016.,   565543.])
# Cumulative counts at iter 738: tensor([47864396.,   566698.])
# Cumulative counts at iter 739: tensor([47929932.,   566698.])
# Cumulative counts at iter 740: tensor([47995468.,   566698.])
# Cumulative counts at iter 741: tensor([48061004.,   566698.])
# Cumulative counts at iter 742: tensor([48126540.,   566698.])
# Cumulative counts at iter 743: tensor([48190960.,   567813.])
# Cumulative counts at iter 744: tensor([48256324.,   567986.])
# Cumulative counts at iter 745: tensor([48321860.,   567986.])
# Cumulative counts at iter 746: tensor([48386184.,   569197.])
# Cumulative counts at iter 747: tensor([48451720.,   569197.])
# Cumulative counts at iter 748: tensor([48517256.,   569197.])
# Cumulative counts at iter 749: tensor([48582792.,   569197.])
# Cumulative counts at iter 750: tensor([48647204.,   570320.])
# Cumulative counts at iter 751: tensor([48712740.,   570320.])
# Cumulative counts at iter 752: tensor([48778276.,   570320.])
# Cumulative counts at iter 753: tensor([48843812.,   570320.])
# Cumulative counts at iter 754: tensor([48909348.,   570320.])
# Cumulative counts at iter 755: tensor([48974884.,   570320.])
# Cumulative counts at iter 756: tensor([49040420.,   570320.])
# Cumulative counts at iter 757: tensor([49105956.,   570320.])
# Cumulative counts at iter 758: tensor([49168960.,   572852.])
# Cumulative counts at iter 759: tensor([49231080.,   576267.])
# Cumulative counts at iter 760: tensor([49295420.,   577463.])
# Cumulative counts at iter 761: tensor([49360956.,   577463.])
# Cumulative counts at iter 762: tensor([49426492.,   577463.])
# Cumulative counts at iter 763: tensor([49492028.,   577463.])
# Cumulative counts at iter 764: tensor([49557564.,   577463.])
# Cumulative counts at iter 765: tensor([49623100.,   577463.])
# Cumulative counts at iter 766: tensor([49688636.,   577463.])
# Cumulative counts at iter 767: tensor([49754172.,   577463.])
# Cumulative counts at iter 768: tensor([49817648.,   579525.])
# Cumulative counts at iter 769: tensor([49879148.,   583560.])
# Cumulative counts at iter 770: tensor([49943264.,   584979.])
# Cumulative counts at iter 771: tensor([50008800.,   584979.])
# Cumulative counts at iter 772: tensor([50074336.,   584979.])
# Cumulative counts at iter 773: tensor([50138672.,   586181.])
# Cumulative counts at iter 774: tensor([50200128.,   590260.])
# Cumulative counts at iter 775: tensor([50262224.,   593702.])
# Cumulative counts at iter 776: tensor([50327760.,   593702.])
# Cumulative counts at iter 777: tensor([50392848.,   594150.])
# Cumulative counts at iter 778: tensor([50458384.,   594150.])
# Cumulative counts at iter 779: tensor([50523920.,   594150.])
# Cumulative counts at iter 780: tensor([50586764.,   596841.])
# ...
# Cumulative counts at iter 2791: tensor([1.8101e+08, 1.9668e+06])
# Cumulative counts at iter 2792: tensor([1.8108e+08, 1.9668e+06])
# Cumulative counts at iter 2793: tensor([1.8114e+08, 1.9668e+06])
# Cumulative counts at iter 2794: tensor([1.8120e+08, 1.9684e+06])
# Cumulative counts at iter 2795: tensor([1.8127e+08, 1.9695e+06])
# Cumulative counts at iter 2796: tensor([1.8133e+08, 1.9695e+06])
# Cumulative counts at iter 2797: tensor([1.8140e+08, 1.9695e+06])
# Cumulative counts at iter 2798: tensor([1.8147e+08, 1.9695e+06])
# Cumulative counts at iter 2799: tensor([1.8153e+08, 1.9695e+06])
# Cumulative counts at iter 2800: tensor([1.8160e+08, 1.9709e+06])
# Cumulative counts at iter 2801: tensor([1.8166e+08, 1.9709e+06])
# Cumulative counts at iter 2802: tensor([1.8173e+08, 1.9709e+06])
# Cumulative counts at iter 2803: tensor([1.8179e+08, 1.9709e+06])
# Cumulative counts at iter 2804: tensor([1.8186e+08, 1.9709e+06])
# Cumulative counts at iter 2805: tensor([1.8192e+08, 1.9709e+06])
# Cumulative counts at iter 2806: tensor([1.8199e+08, 1.9709e+06])
# Cumulative counts at iter 2807: tensor([1.8205e+08, 1.9716e+06])
# Cumulative counts at iter 2808: tensor([1.8212e+08, 1.9734e+06])
# Cumulative counts at iter 2809: tensor([1.8218e+08, 1.9734e+06])
# Cumulative counts at iter 2810: tensor([1.8225e+08, 1.9738e+06])
# Cumulative counts at iter 2811: tensor([1.8231e+08, 1.9738e+06])
# Cumulative counts at iter 2812: tensor([1.8238e+08, 1.9738e+06])
# Cumulative counts at iter 2813: tensor([1.8244e+08, 1.9738e+06])
# Cumulative counts at iter 2814: tensor([1.8251e+08, 1.9738e+06])
# Cumulative counts at iter 2815: tensor([1.8258e+08, 1.9738e+06])
# Cumulative counts at iter 2816: tensor([1.8264e+08, 1.9738e+06])
# Cumulative counts at iter 2817: tensor([1.8271e+08, 1.9750e+06])
# Cumulative counts at iter 2818: tensor([1.8277e+08, 1.9750e+06])
# Cumulative counts at iter 2819: tensor([1.8284e+08, 1.9750e+06])
# Cumulative counts at iter 2820: tensor([1.8290e+08, 1.9779e+06])
# Cumulative counts at iter 2821: tensor([1.8296e+08, 1.9811e+06])
# Cumulative counts at iter 2822: tensor([1.8303e+08, 1.9811e+06])
# Cumulative counts at iter 2823: tensor([1.8309e+08, 1.9811e+06])
# Cumulative counts at iter 2824: tensor([1.8316e+08, 1.9811e+06])
# Cumulative counts at iter 2825: tensor([1.8322e+08, 1.9811e+06])
# Cumulative counts at iter 2826: tensor([1.8329e+08, 1.9843e+06])
# Cumulative counts at iter 2827: tensor([1.8335e+08, 1.9868e+06])
# Cumulative counts at iter 2828: tensor([1.8341e+08, 1.9868e+06])
# Cumulative counts at iter 2829: tensor([1.8348e+08, 1.9868e+06])
# Cumulative counts at iter 2830: tensor([1.8354e+08, 1.9887e+06])
# Cumulative counts at iter 2831: tensor([1.8361e+08, 1.9891e+06])
# Cumulative counts at iter 2832: tensor([1.8367e+08, 1.9912e+06])
# Cumulative counts at iter 2833: tensor([1.8373e+08, 1.9943e+06])
# Cumulative counts at iter 2834: tensor([1.8380e+08, 1.9943e+06])
# Cumulative counts at iter 2835: tensor([1.8387e+08, 1.9943e+06])
# Cumulative counts at iter 2836: tensor([1.8393e+08, 1.9943e+06])
# Cumulative counts at iter 2837: tensor([1.8400e+08, 1.9943e+06])
# Cumulative counts at iter 2838: tensor([1.8406e+08, 1.9943e+06])
# Cumulative counts at iter 2839: tensor([1.8413e+08, 1.9943e+06])
# Cumulative counts at iter 2840: tensor([1.8419e+08, 1.9943e+06])
# Cumulative counts at iter 2841: tensor([1.8426e+08, 1.9943e+06])
# Cumulative counts at iter 2842: tensor([1.8432e+08, 1.9969e+06])
# Cumulative counts at iter 2843: tensor([1.8439e+08, 1.9982e+06])
# Cumulative counts at iter 2844: tensor([1.8445e+08, 1.9982e+06])
# Cumulative counts at iter 2845: tensor([1.8452e+08, 1.9982e+06])
# Cumulative counts at iter 2846: tensor([1.8458e+08, 1.9982e+06])
# Cumulative counts at iter 2847: tensor([1.8465e+08, 1.9982e+06])
# Cumulative counts at iter 2848: tensor([1.8471e+08, 1.9982e+06])
# Cumulative counts at iter 2849: tensor([1.8478e+08, 2.0007e+06])
# Cumulative counts at iter 2850: tensor([1.8484e+08, 2.0007e+06])
# Cumulative counts at iter 2851: tensor([1.8491e+08, 2.0036e+06])
# Cumulative counts at iter 2852: tensor([1.8497e+08, 2.0063e+06])
# Cumulative counts at iter 2853: tensor([1.8503e+08, 2.0094e+06])
# Cumulative counts at iter 2854: tensor([1.8510e+08, 2.0094e+06])
# Cumulative counts at iter 2855: tensor([1.8516e+08, 2.0094e+06])
# Cumulative counts at iter 2856: tensor([1.8523e+08, 2.0094e+06])
# Cumulative counts at iter 2857: tensor([1.8529e+08, 2.0098e+06])
# Cumulative counts at iter 2858: tensor([1.8536e+08, 2.0098e+06])
# Cumulative counts at iter 2859: tensor([1.8542e+08, 2.0098e+06])
# Cumulative counts at iter 2860: tensor([1.8549e+08, 2.0098e+06])
# Cumulative counts at iter 2861: tensor([1.8555e+08, 2.0098e+06])
# Cumulative counts at iter 2862: tensor([1.8562e+08, 2.0098e+06])
# Cumulative counts at iter 2863: tensor([1.8569e+08, 2.0098e+06])
# Cumulative counts at iter 2864: tensor([1.8575e+08, 2.0098e+06])
# Cumulative counts at iter 2865: tensor([1.8582e+08, 2.0098e+06])
# Cumulative counts at iter 2866: tensor([1.8588e+08, 2.0124e+06])
# Cumulative counts at iter 2867: tensor([1.8594e+08, 2.0156e+06])
# Cumulative counts at iter 2868: tensor([1.8600e+08, 2.0187e+06])
# Cumulative counts at iter 2869: tensor([1.8607e+08, 2.0187e+06])
# Cumulative counts at iter 2870: tensor([1.8613e+08, 2.0215e+06])
# Cumulative counts at iter 2871: tensor([1.8620e+08, 2.0215e+06])
# Cumulative counts at iter 2872: tensor([1.8626e+08, 2.0215e+06])
# Cumulative counts at iter 2873: tensor([1.8633e+08, 2.0215e+06])
# Cumulative counts at iter 2874: tensor([1.8639e+08, 2.0215e+06])
# Cumulative counts at iter 2875: tensor([1.8646e+08, 2.0215e+06])
# Cumulative counts at iter 2876: tensor([1.8653e+08, 2.0215e+06])
# Cumulative counts at iter 2877: tensor([1.8659e+08, 2.0215e+06])
# Cumulative counts at iter 2878: tensor([1.8666e+08, 2.0215e+06])
# Cumulative counts at iter 2879: tensor([1.8672e+08, 2.0215e+06])
# Cumulative counts at iter 2880: tensor([1.8679e+08, 2.0215e+06])
# Cumulative counts at iter 2881: tensor([1.8685e+08, 2.0215e+06])
# Cumulative counts at iter 2882: tensor([1.8692e+08, 2.0215e+06])
# Cumulative counts at iter 2883: tensor([1.8698e+08, 2.0215e+06])
# Cumulative counts at iter 2884: tensor([1.8705e+08, 2.0215e+06])
# Cumulative counts at iter 2885: tensor([1.8712e+08, 2.0215e+06])
# Cumulative counts at iter 2886: tensor([1.8718e+08, 2.0215e+06])
# Cumulative counts at iter 2887: tensor([1.8725e+08, 2.0215e+06])
# Cumulative counts at iter 2888: tensor([1.8731e+08, 2.0215e+06])
# Cumulative counts at iter 2889: tensor([1.8738e+08, 2.0215e+06])
# Cumulative counts at iter 2890: tensor([1.8744e+08, 2.0215e+06])
# Cumulative counts at iter 2891: tensor([1.8751e+08, 2.0215e+06])
# Cumulative counts at iter 2892: tensor([1.8757e+08, 2.0215e+06])
# Cumulative counts at iter 2893: tensor([1.8764e+08, 2.0215e+06])
# Cumulative counts at iter 2894: tensor([1.8771e+08, 2.0215e+06])
# Cumulative counts at iter 2895: tensor([1.8777e+08, 2.0215e+06])
# Cumulative counts at iter 2896: tensor([1.8784e+08, 2.0228e+06])
# Cumulative counts at iter 2897: tensor([1.8790e+08, 2.0259e+06])
# Cumulative counts at iter 2898: tensor([1.8796e+08, 2.0283e+06])
# Cumulative counts at iter 2899: tensor([1.8802e+08, 2.0300e+06])
# Cumulative counts at iter 2900: tensor([1.8809e+08, 2.0319e+06])
# Cumulative counts at iter 2901: tensor([1.8815e+08, 2.0332e+06])
# Cumulative counts at iter 2902: tensor([1.8822e+08, 2.0342e+06])
# Cumulative counts at iter 2903: tensor([1.8828e+08, 2.0342e+06])
# Cumulative counts at iter 2904: tensor([1.8835e+08, 2.0342e+06])
# Cumulative counts at iter 2905: tensor([1.8841e+08, 2.0342e+06])
# Cumulative counts at iter 2906: tensor([1.8848e+08, 2.0342e+06])
# Cumulative counts at iter 2907: tensor([1.8854e+08, 2.0342e+06])
# Cumulative counts at iter 2908: tensor([1.8861e+08, 2.0342e+06])
# Cumulative counts at iter 2909: tensor([1.8868e+08, 2.0342e+06])
# Cumulative counts at iter 2910: tensor([1.8874e+08, 2.0342e+06])
# Cumulative counts at iter 2911: tensor([1.8881e+08, 2.0342e+06])
# Cumulative counts at iter 2912: tensor([1.8887e+08, 2.0342e+06])
# Cumulative counts at iter 2913: tensor([1.8894e+08, 2.0342e+06])
# Cumulative counts at iter 2914: tensor([1.8900e+08, 2.0348e+06])
# Cumulative counts at iter 2915: tensor([1.8907e+08, 2.0363e+06])
# Cumulative counts at iter 2916: tensor([1.8913e+08, 2.0385e+06])
# Cumulative counts at iter 2917: tensor([1.8919e+08, 2.0407e+06])
# Cumulative counts at iter 2918: tensor([1.8926e+08, 2.0439e+06])
# Cumulative counts at iter 2919: tensor([1.8932e+08, 2.0452e+06])
# Cumulative counts at iter 2920: tensor([1.8939e+08, 2.0453e+06])
# Cumulative counts at iter 2921: tensor([1.8945e+08, 2.0454e+06])
# Cumulative counts at iter 2922: tensor([1.8951e+08, 2.0468e+06])
# Cumulative counts at iter 2923: tensor([1.8958e+08, 2.0486e+06])
# Cumulative counts at iter 2924: tensor([1.8964e+08, 2.0486e+06])
# Cumulative counts at iter 2925: tensor([1.8971e+08, 2.0486e+06])
# Cumulative counts at iter 2926: tensor([1.8978e+08, 2.0486e+06])
# Cumulative counts at iter 2927: tensor([1.8984e+08, 2.0486e+06])
# Cumulative counts at iter 2928: tensor([1.8991e+08, 2.0486e+06])
# Cumulative counts at iter 2929: tensor([1.8997e+08, 2.0486e+06])
# Cumulative counts at iter 2930: tensor([1.9004e+08, 2.0486e+06])
# Cumulative counts at iter 2931: tensor([1.9010e+08, 2.0491e+06])
# Cumulative counts at iter 2932: tensor([1.9017e+08, 2.0507e+06])
# Cumulative counts at iter 2933: tensor([1.9023e+08, 2.0518e+06])
# Cumulative counts at iter 2934: tensor([1.9030e+08, 2.0522e+06])
# Cumulative counts at iter 2935: tensor([1.9036e+08, 2.0532e+06])
# Cumulative counts at iter 2936: tensor([1.9043e+08, 2.0532e+06])
# Cumulative counts at iter 2937: tensor([1.9049e+08, 2.0532e+06])
# Cumulative counts at iter 2938: tensor([1.9056e+08, 2.0532e+06])
# Cumulative counts at iter 2939: tensor([1.9062e+08, 2.0532e+06])
# Cumulative counts at iter 2940: tensor([1.9069e+08, 2.0532e+06])
# Cumulative counts at iter 2941: tensor([1.9075e+08, 2.0532e+06])
# Cumulative counts at iter 2942: tensor([1.9082e+08, 2.0532e+06])
# Cumulative counts at iter 2943: tensor([1.9088e+08, 2.0532e+06])
# Cumulative counts at iter 2944: tensor([1.9095e+08, 2.0532e+06])
# Cumulative counts at iter 2945: tensor([1.9102e+08, 2.0532e+06])
# Cumulative counts at iter 2946: tensor([1.9108e+08, 2.0532e+06])
# Cumulative counts at iter 2947: tensor([1.9115e+08, 2.0532e+06])
# Cumulative counts at iter 2948: tensor([1.9121e+08, 2.0532e+06])
# Cumulative counts at iter 2949: tensor([1.9128e+08, 2.0532e+06])
# Cumulative counts at iter 2950: tensor([1.9134e+08, 2.0532e+06])
# Cumulative counts at iter 2951: tensor([1.9141e+08, 2.0532e+06])
# Cumulative counts at iter 2952: tensor([1.9147e+08, 2.0532e+06])
# Cumulative counts at iter 2953: tensor([1.9154e+08, 2.0532e+06])
# Cumulative counts at iter 2954: tensor([1.9160e+08, 2.0551e+06])
# Cumulative counts at iter 2955: tensor([1.9167e+08, 2.0571e+06])
# Cumulative counts at iter 2956: tensor([1.9173e+08, 2.0571e+06])
# Cumulative counts at iter 2957: tensor([1.9180e+08, 2.0571e+06])
# Cumulative counts at iter 2958: tensor([1.9186e+08, 2.0577e+06])
# Cumulative counts at iter 2959: tensor([1.9193e+08, 2.0577e+06])
# Cumulative counts at iter 2960: tensor([1.9199e+08, 2.0577e+06])
# Cumulative counts at iter 2961: tensor([1.9206e+08, 2.0577e+06])
# Cumulative counts at iter 2962: tensor([1.9213e+08, 2.0577e+06])
# Cumulative counts at iter 2963: tensor([1.9219e+08, 2.0577e+06])
# Cumulative counts at iter 2964: tensor([1.9226e+08, 2.0577e+06])
# Cumulative counts at iter 2965: tensor([1.9232e+08, 2.0577e+06])
# Cumulative counts at iter 2966: tensor([1.9239e+08, 2.0577e+06])
# Cumulative counts at iter 2967: tensor([1.9245e+08, 2.0586e+06])
# Cumulative counts at iter 2968: tensor([1.9252e+08, 2.0586e+06])
# Cumulative counts at iter 2969: tensor([1.9258e+08, 2.0605e+06])
# Cumulative counts at iter 2970: tensor([1.9265e+08, 2.0605e+06])
# Cumulative counts at iter 2971: tensor([1.9271e+08, 2.0623e+06])
# Cumulative counts at iter 2972: tensor([1.9278e+08, 2.0623e+06])
# Cumulative counts at iter 2973: tensor([1.9284e+08, 2.0633e+06])
# Cumulative counts at iter 2974: tensor([1.9291e+08, 2.0633e+06])
# Cumulative counts at iter 2975: tensor([1.9297e+08, 2.0633e+06])
# Cumulative counts at iter 2976: tensor([1.9304e+08, 2.0633e+06])
# Cumulative counts at iter 2977: tensor([1.9310e+08, 2.0633e+06])
# Cumulative counts at iter 2978: tensor([1.9317e+08, 2.0633e+06])
# Cumulative counts at iter 2979: tensor([1.9323e+08, 2.0633e+06])
# Cumulative counts at iter 2980: tensor([1.9330e+08, 2.0633e+06])
# Cumulative counts at iter 2981: tensor([1.9337e+08, 2.0633e+06])
# Cumulative counts at iter 2982: tensor([1.9343e+08, 2.0638e+06])
# Cumulative counts at iter 2983: tensor([1.9350e+08, 2.0638e+06])
# Cumulative counts at iter 2984: tensor([1.9356e+08, 2.0638e+06])
# Cumulative counts at iter 2985: tensor([1.9363e+08, 2.0641e+06])
# Cumulative counts at iter 2986: tensor([1.9369e+08, 2.0641e+06])
# Cumulative counts at iter 2987: tensor([1.9376e+08, 2.0641e+06])
# Cumulative counts at iter 2988: tensor([1.9382e+08, 2.0641e+06])
# Cumulative counts at iter 2989: tensor([1.9389e+08, 2.0651e+06])
# Cumulative counts at iter 2990: tensor([1.9395e+08, 2.0652e+06])
# Cumulative counts at iter 2991: tensor([1.9402e+08, 2.0655e+06])
# Cumulative counts at iter 2992: tensor([1.9408e+08, 2.0655e+06])
# Cumulative counts at iter 2993: tensor([1.9415e+08, 2.0655e+06])
# Cumulative counts at iter 2994: tensor([1.9421e+08, 2.0655e+06])
# Cumulative counts at iter 2995: tensor([1.9428e+08, 2.0663e+06])
# Cumulative counts at iter 2996: tensor([1.9435e+08, 2.0663e+06])
# Cumulative counts at iter 2997: tensor([1.9441e+08, 2.0663e+06])
# Cumulative counts at iter 2998: tensor([1.9448e+08, 2.0663e+06])
# Cumulative counts at iter 2999: tensor([1.9454e+08, 2.0663e+06])
# Cumulative counts at iter 3000: tensor([1.9461e+08, 2.0663e+06])
# Cumulative counts at iter 3001: tensor([1.9467e+08, 2.0663e+06])
# Cumulative counts at iter 3002: tensor([1.9474e+08, 2.0663e+06])
# Cumulative counts at iter 3003: tensor([1.9480e+08, 2.0663e+06])
# Cumulative counts at iter 3004: tensor([1.9487e+08, 2.0663e+06])
# Cumulative counts at iter 3005: tensor([1.9493e+08, 2.0663e+06])
# Cumulative counts at iter 3006: tensor([1.9500e+08, 2.0663e+06])
# Cumulative counts at iter 3007: tensor([1.9507e+08, 2.0663e+06])
# Cumulative counts at iter 3008: tensor([1.9513e+08, 2.0663e+06])
# Cumulative counts at iter 3009: tensor([1.9520e+08, 2.0663e+06])
# Cumulative counts at iter 3010: tensor([1.9526e+08, 2.0663e+06])
# Cumulative counts at iter 3011: tensor([1.9533e+08, 2.0663e+06])
# Cumulative counts at iter 3012: tensor([1.9539e+08, 2.0663e+06])
# Cumulative counts at iter 3013: tensor([1.9546e+08, 2.0663e+06])
# Cumulative counts at iter 3014: tensor([1.9552e+08, 2.0663e+06])
# Cumulative counts at iter 3015: tensor([1.9559e+08, 2.0667e+06])
# Cumulative counts at iter 3016: tensor([1.9565e+08, 2.0678e+06])
# Cumulative counts at iter 3017: tensor([1.9572e+08, 2.0678e+06])
# Cumulative counts at iter 3018: tensor([1.9579e+08, 2.0678e+06])
# Cumulative counts at iter 3019: tensor([1.9585e+08, 2.0678e+06])
# Cumulative counts at iter 3020: tensor([1.9592e+08, 2.0678e+06])
# Cumulative counts at iter 3021: tensor([1.9598e+08, 2.0678e+06])
# Cumulative counts at iter 3022: tensor([1.9605e+08, 2.0678e+06])
# Cumulative counts at iter 3023: tensor([1.9611e+08, 2.0678e+06])
# Cumulative counts at iter 3024: tensor([1.9618e+08, 2.0678e+06])
# Cumulative counts at iter 3025: tensor([1.9624e+08, 2.0680e+06])
# Cumulative counts at iter 3026: tensor([1.9631e+08, 2.0680e+06])
# Cumulative counts at iter 3027: tensor([1.9637e+08, 2.0690e+06])
# Cumulative counts at iter 3028: tensor([1.9644e+08, 2.0690e+06])
# Cumulative counts at iter 3029: tensor([1.9650e+08, 2.0698e+06])
# Cumulative counts at iter 3030: tensor([1.9657e+08, 2.0698e+06])
# Cumulative counts at iter 3031: tensor([1.9664e+08, 2.0698e+06])
# Class weights: tensor([0.0104, 0.9896])
# train : 3032
# valid : 455
# test : 442
# Valid Loss at epoch: 0 is 0.660316060509598
# Valid IoU at epoch: 0 is 0.4909172950532917
# Valid Pixel acc at epoch: 0 is 0.9802868874150709
# (0.660316060509598, 0.4909172950532917, 0.9802868874150709)

# %%
best_iou_score, train_loss_per_epoch, train_iou_per_epoch, train_acc_per_epoch, valid_loss_per_epoch, valid_iou_per_epoch, valid_acc_per_epoch = train(train_loader, valid_loader, model_dict)

# %%
print(f"Best IoU score: {best_iou_score}")
util.plot_train_valid(train_loss_per_epoch, valid_loss_per_epoch, name='Loss')
util.plot_train_valid(train_acc_per_epoch, valid_acc_per_epoch, name='Accuracy')
util.plot_train_valid(train_iou_per_epoch, valid_iou_per_epoch, name='Intersection over Union')

# %%
test_loss, test_iou, test_acc, image_outputs, image_labels = modelTest(test_loader, model_dict)
print(f"Test Loss is {test_loss}")
print(f"Test IoU is {test_iou}")
print(f"Test Pixel acc is {test_acc}")

# %%
image_index = 4
_, pred_mask = torch.max(pred[image_index].cpu().data, 0)
pred_mask = pred_mask.numpy()
true_mask = true[image_index].cpu().data.numpy()
# visualize_image(pred_mask, true_mask)
visualize_image(pred[image_index].cpu(), true[image_index].cpu())

# %%
"""
# ------ GET SAMPLE IMAGE FOR REPORT -------
test_sample_dataset = voc.VOC('test', transforms=sample_transform)
test_sample_loader = DataLoader(dataset=test_sample_dataset, batch_size=1, shuffle=False)
model.eval()
# untransformed original image
orig_inp, _ = next(iter(test_sample_loader))

# transformed image for input to network
inp, label = next(iter(test_loader))
inp = inp.to(device)
label = label.to(device)
output = model(inp)
_, pred = torch.max(output, dim=1)

util.save_sample(np.array(orig_inp[0].cpu(), dtype=np.uint8), label[0].cpu(), pred[0].cpu())
model.train()
# -------------------------------------------
"""

# housekeeping
gc.collect()
torch.cuda.empty_cache()
